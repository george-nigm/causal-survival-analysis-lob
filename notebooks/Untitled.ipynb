# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/georgii_nigm/Applications/VS Code projects/academic_causal_portfolio/notebooks

# %%
granger_bt = pd.read_csv('../output-scratch/10. 07.08 | 21-17 | pinnacle-2000-2021-grangers_causation_matrix/returns_bt.csv')

# %%
granger_bt
# Out:
#             Date        KW        MW        NR        ZC        ZL        ZM  \
# 0     2000-01-04 -0.009003 -0.025644 -0.001327 -0.037725 -0.004629  0.000000
# 1     2000-01-05  0.003407 -0.014780  0.002924 -0.035439  0.002464  0.000000
# 2     2000-01-06 -0.004074 -0.004064  0.003379 -0.001633 -0.007519 -0.033072
# 3     2000-01-07  0.000682  0.049882 -0.005415  0.016357  0.002198  0.000000
# 4     2000-01-10  0.001363  0.019036 -0.001129  0.019222  0.000570 -0.009275
# ...          ...       ...       ...       ...       ...       ...       ...
# 5673  2021-12-07  0.010491  0.026544 -0.001496  0.029075  0.009578  0.013944
# 5674  2021-12-08  0.008721 -0.006256 -0.000374 -0.007152 -0.000756  0.012279
# 5675  2021-12-09 -0.004940 -0.006047 -0.002023 -0.001000 -0.004754  0.001941
# 5676  2021-12-10  0.003448  0.001149  0.003753 -0.002434 -0.000760  0.000000
# 5677  2021-12-13 -0.004261 -0.000830 -0.002842 -0.006600 -0.005148  0.012107
#
# ...

# %%
granger_df = pd.read_csv('../output-scratch/10. 07.08 | 21-17 | pinnacle-2000-2021-grangers_causation_matrix/returns.csv')

# %%
sum(granger_df.iloc[:,1:].sum().values)
# Out:
# 36.337347933384464

# %%
granger_df.iloc[:,1:].sum(axis = 1)
# Out:
# 0      -0.423393
# 1      -0.166541
# 2      -0.193635
# 3       0.383261
# 4       0.223774
#           ...
# 5673    0.301127
# 5674    0.074393
# 5675   -0.178134
# 5676    0.152519
# 5677   -0.128535
# Length: 5678, dtype: float64
